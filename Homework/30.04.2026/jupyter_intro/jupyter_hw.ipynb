# %% [markdown]
# # QUESTION1
# `Giora`<br>
# <font color=red>Glovatsky</font>

# %% [markdown]
# ## Question 2
# **0548888888**<br>
# ***My home address :)***

# %% [markdown]
# ### QUESTION3
#
# The pyramid<br>
# > |
# >> |
# >>> |
# >>>> |
# >>>>> |

# %% [markdown]
# ### QUESTION4
# $a^2 + b^2 = c^2$

# %%
# QUESTION5
x = 3
y = 3.141
AREA = y * x ** 2

# Printing variables values
print(f"x = {x}")
print(f"y = {y}")
print(f"AREA = {AREA}\n")

# Printing variables types
print(f"x type = {type(x)}")
print(f"y type = {type(y)}")
print(f"AREA type = {type(AREA)}")
# Out:
# x = 3
# y = 3.141
# AREA = 28.269
#
# x type = <class 'int'>
# y type = <class 'float'>
# AREA type = <class 'float'>

# %%
# QUESTION6

print(AREA // 4 <= 7)
print(AREA / 4 < 7)
print(not AREA // 4 <= 7 and AREA / 4 < 7)
# Out:
# True
# False
# False

# %%
# QUESTION7

str_name = "Giora_Glovatsky Giora Glovatsky"

list_name = str_name.split()
# Printing all the values in the even indexes
for i in range(len(list_name)):
    if i % 2 == 0:
        print(list_name[i])
# Printing all the values in the odd indexes
for i in range(len(list_name)):
    if i % 2 == 1:
        print(list_name[i])
# Out:
# Giora_Glovatsky
# Glovatsky
# Giora

# %%
# QUESTION8

a = "#####"
b = "*****"
c = "Giora Glovatsky"

# The concatenated name
concatenate = a + c + b

# Calculating the first name and last name len
last_len = concatenate.find(b[0]) - concatenate.find(" ") - 1
name_len = concatenate.find(" ") - concatenate.rfind(a[0]) - 1

# Printing the length of the first name + last name
print(f"First name length: {name_len}, last name length: {last_len}.")
# Out:
# Name length: 5, last name length: 9

# %%
# Question 9

import numpy as np
import matplotlib.pyplot as plt

N = 2
x = [0.25, 0.75]   # left circle and right circle, same height
y = [0.5, 0.5]
color = 'r'

area = np.pi * 35000


plt.scatter(x, y, s=area, c=color, alpha=1)
plt.show()
